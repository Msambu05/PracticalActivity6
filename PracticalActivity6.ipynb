# %% [markdown]
# Activity 6

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as nm

# %%
#load a dataset
df = pd.read_csv("C:/Users/sambu/OneDrive/Desktop/dataset - 2020-09-24.csv")

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of                      Name  Jersey Number                     Club    Position  \
# 0              Bernd Leno            1.0                  Arsenal  Goalkeeper
# 1              Matt Macey           33.0                  Arsenal  Goalkeeper
# 2    Rúnar Alex Rúnarsson           13.0                  Arsenal  Goalkeeper
# 3         Héctor Bellerín            2.0                  Arsenal    Defender
# 4          Kieran Tierney            3.0                  Arsenal    Defender
# ..                    ...            ...                      ...         ...
# 566            Pedro Neto            7.0  Wolverhampton-Wanderers     Forward
# 567          Raúl Jiménez            9.0  Wolverhampton-Wanderers     Forward
# 568          Adama Traoré           37.0  Wolverhampton-Wanderers     Forward
# 569           Fábio Silva           17.0  Wolverhampton-Wanderers     Forward
# 570      Leonardo Campana           30.0  Wolverhampton-Wanderers     Forward
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 59 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    571 non-null    object
#  1   Jersey Number           563 non-null    float64
#  2   Club                    571 non-null    object
#  3   Position                571 non-null    object
#  4   Nationality             570 non-null    object
#  5   Age                     570 non-null    float64
#  6   Appearances             571 non-null    int64
#  7   Wins                    571 non-null    int64
#  8   Losses                  571 non-null    int64
#  9   Goals                   571 non-null    int64
#  10  Goals per match         309 non-null    float64
#  11  Headed goals            502 non-null    float64
#  12  Goals with right foot   502 non-null    float64
#  13  Goals with left foot    502 non-null    float64
# ...

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Name                        0
# Jersey Number               8
# Club                        0
# Position                    0
# Nationality                 1
# Age                         1
# Appearances                 0
# Wins                        0
# Losses                      0
# Goals                       0
# Goals per match           262
# Headed goals               69
# Goals with right foot      69
# Goals with left foot       69
# Penalties scored          262
# Freekicks scored          262
# Shots                     262
# Shots on target           262
# Shooting accuracy %       262
# Hit woodwork               69
# Big chances missed        262
# Clean sheets              309
# Goals conceded            309
# Tackles                    69
# Tackle success %          181
# Last man tackles          378
# Blocked shots              69
# Interceptions              69
# Clearances                 69
# Headed Clearance           69
# Clearances off line       378
# ...

# %%
duplicate = df.duplicated().sum()
print('Number of duplicate entries is:', duplicate)
# Out:
# Number of duplicate entries is: 0

# %%
df.dtypes
# Out:
# Name                       object
# Jersey Number             float64
# Club                       object
# Position                   object
# Nationality                object
# Age                       float64
# Appearances                 int64
# Wins                        int64
# Losses                      int64
# Goals                       int64
# Goals per match           float64
# Headed goals              float64
# Goals with right foot     float64
# Goals with left foot      float64
# Penalties scored          float64
# Freekicks scored          float64
# Shots                     float64
# Shots on target           float64
# Shooting accuracy %        object
# Hit woodwork              float64
# Big chances missed        float64
# Clean sheets              float64
# Goals conceded            float64
# Tackles                   float64
# Tackle success %           object
# Last man tackles          float64
# Blocked shots             float64
# ...

# %%
df.size
# Out:
# 33689

# %%
df.shape
# Out:
# (571, 59)

# %%
df.columns
# Out:
# Index(['Name', 'Jersey Number', 'Club', 'Position', 'Nationality', 'Age',
#        'Appearances', 'Wins', 'Losses', 'Goals', 'Goals per match',
#        'Headed goals', 'Goals with right foot', 'Goals with left foot',
#        'Penalties scored', 'Freekicks scored', 'Shots', 'Shots on target',
#        'Shooting accuracy %', 'Hit woodwork', 'Big chances missed',
#        'Clean sheets', 'Goals conceded', 'Tackles', 'Tackle success %',
#        'Last man tackles', 'Blocked shots', 'Interceptions', 'Clearances',
#        'Headed Clearance', 'Clearances off line', 'Recoveries', 'Duels won',
#        'Duels lost', 'Successful 50/50s', 'Aerial battles won',
#        'Aerial battles lost', 'Own goals', 'Errors leading to goal', 'Assists',
#        'Passes', 'Passes per match', 'Big chances created', 'Crosses',
#        'Cross accuracy %', 'Through balls', 'Accurate long balls', 'Saves',
#        'Penalties saved', 'Punches', 'High Claims', 'Catches',
# ...

# %%
Name = ['Xhaka', 'Kukayo Saka', 'Dani Ceballos', 'David Luiz', 'Matt Macey']
JerseyNumber = [34, 7, 8, 23, 1]

plt.scatter(Name, JerseyNumber)
plt.xlabel('Name')
plt.ylabel('Jersey Number')
plt.title('Relationship Between Players and Jersey Number')
plt.show()

# %%
#Generate random data
df = nm.random.normal(loc = 20, scale = 5, size = 365)
plt.hist(df, bins = 25, color = 'lightblue', edgecolor = 'black')
plt.xlabel('Goals per Match')
plt.ylabel('Goals')
plt.title('Distribution of Goals and Goals per Match')
plt.show()

# %%
df = np.random.normal(loc = 20, scale = 5, size = 10)

plt.figure(figsize=(6, 6)) 
plt.bar(nm.arange(len(df)), games, color = 'yellow', alpha = 1, label = 'Games') 
plt.bar(nm.arange(len(df)), wins, color = 'skyblue', alpha= 1, label = 'Wins') 
plt.xlabel('Days')
plt.ylabel('Average')
plt.title('Average Wins by Games')
plt.legend() 
plt.show()

# %%
Name = ['Bernd Leno', 'Hector Bellerin', 'Jay Rodriguez', 'Ashley Barnes', 'Alex Iwobi']
Appearances = [64, 160, 178, 155, 126]

plt.figure(figsize = (6,6))
plt.pie(Appearances, labels = Name, autopct = '%1.1f%%', startangle = 140)
plt.title("Players and Appearances")
plt.show()

# %%
Goals = np.random.normal(70, 10, 100)
Goals = np.append(test_scores, [50, 34, 25, 65, 30]) 

plt.figure(figsize=(6, 8))
plt.boxplot(Goals, vert=True, patch_artist=True, meanline=True, showmeans=True)
plt.title('Distribution of Goals')
plt.ylabel('Goals')
plt.grid(True)
plt.show()
